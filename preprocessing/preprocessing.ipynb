# %%
import pandas as pd
import numpy as np 
import os 
import sys

# %%
DATA_ROOT = '../data'
data_file = os.path.join(DATA_ROOT, "dermatology.csv")
data = pd.read_csv(data_file) 
data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
# Add "patient id" column 
n = len(data)
data['pid'] = range(1, n + 1)
pid_column = data.pop('pid') 
data.insert(0, 'pid', pid_column) 
data
# Out:
#      pid  erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0      1         2        2                 0        3                   0
# 1      2         3        3                 3        2                   1
# 2      3         2        1                 2        3                   1
# 3      4         2        2                 2        0                   0
# 4      5         2        3                 2        2                   2
# ..   ...       ...      ...               ...      ...                 ...
# 361  362         2        1                 1        0                   1
# 362  363         3        2                 1        0                   1
# 363  364         3        2                 2        2                   3
# 364  365         2        1                 3        1                   2
# 365  366         3        2                 2        0                   0
#
# ...

# %%
data.loc[36]
# Out:
# pid                                         37
# erythema                                     2
# scaling                                      1
# definite_borders                             2
# itching                                      3
# koebner_phenomenon                           2
# polygonal_papules                            3
# follicular_papules                           0
# oral_mucosal_involvement                     2
# knee_and_elbow_involvement                   0
# scalp_involvement                            0
# family_history                               1
# melanin_incontinence                         1
# eosinophils_in_the_infiltrate                0
# PNL_infiltrate                               0
# fibrosis_of_papillary_dermis                 0
# exocytosis                                   2
# acanthosis                                   1
# hyperkeratosis                               1
# parakeratosis                                2
# ...

# %%
# there are four cases with unknown age. 
# Replace ? with NaN. 
# These values are to be imputed in the training pipeline.
data = data.replace('?', pd.NA)
data
# Out:
#      pid  erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0      1         2        2                 0        3                   0
# 1      2         3        3                 3        2                   1
# 2      3         2        1                 2        3                   1
# 3      4         2        2                 2        0                   0
# 4      5         2        3                 2        2                   2
# ..   ...       ...      ...               ...      ...                 ...
# 361  362         2        1                 1        0                   1
# 362  363         3        2                 1        0                   1
# 363  364         3        2                 2        2                   3
# 364  365         2        1                 3        1                   2
# 365  366         3        2                 2        0                   0
#
# ...

# %%
for col in data.columns:
    # df["a"] = pd.to_numeric(df["a"])
    data[col] = pd.to_numeric(data[col])
data
print(print_non_numeric(data))
# Out:
# pid
# erythema
# scaling
# definite_borders
# itching
# koebner_phenomenon
# polygonal_papules
# follicular_papules
# oral_mucosal_involvement
# knee_and_elbow_involvement
# scalp_involvement
# family_history
# melanin_incontinence
# eosinophils_in_the_infiltrate
# PNL_infiltrate
# fibrosis_of_papillary_dermis
# exocytosis
# acanthosis
# hyperkeratosis
# parakeratosis
# clubbing_of_rete_ridges
# elongation_of_rete_ridges
# thinning_of_the_suprapapillary_epidermis
# spongiform_pustule
# munro_microabcess
# focal_hypergranulosis
# disappearance_of_granular_layer
# vacuolisation_and_damage_of_basal_layer
# spongiosis
# saw-tooth_appearance_of_retes
# follicular_horn_plug
# perifollicular_parakeratosis
# inflammatory_monoluclear_inflitrate
# band-like_infiltrate
# age
# diagnosis
# None

# %%
# Now we should be able to see NaN instead of '?'
data.loc[36]
# Out:
# pid                                         37.0
# erythema                                     2.0
# scaling                                      1.0
# definite_borders                             2.0
# itching                                      3.0
# koebner_phenomenon                           2.0
# polygonal_papules                            3.0
# follicular_papules                           0.0
# oral_mucosal_involvement                     2.0
# knee_and_elbow_involvement                   0.0
# scalp_involvement                            0.0
# family_history                               1.0
# melanin_incontinence                         1.0
# eosinophils_in_the_infiltrate                0.0
# PNL_infiltrate                               0.0
# fibrosis_of_papillary_dermis                 0.0
# exocytosis                                   2.0
# acanthosis                                   1.0
# hyperkeratosis                               1.0
# ...

# %% [markdown]
# ## Save the multimodal features

# %%
data.to_csv(os.path.join(DATA_ROOT, 'clincopathology_features.csv'))

# %% [markdown]
# ## Extract single-modality features

# %%
clinical_columns = [
    'erythema',
    'scaling',
    'definite_borders',
    'itching',
    'koebner_phenomenon',
    'polygonal_papules',
    'follicular_papules',
    'oral_mucosal_involvement',
    'knee_and_elbow_involvement',
    'scalp_involvement',
    'family_history',
    'age',
    'diagnosis'
]

pathology_columns = [
    'melanin_incontinence',
    'eosinophils_in_the_infiltrate',
    'PNL_infiltrate',
    'fibrosis_of_papillary_dermis',
    'exocytosis',
    'acanthosis',
    'hyperkeratosis',
    'parakeratosis',
    'clubbing_of_rete_ridges',
    'elongation_of_rete_ridges',
    'thinning_of_the_suprapapillary_epidermis',
    'spongiform_pustule',
    'munro_microabcess',
    'focal_hypergranulosis',
    'disappearance_of_granular_layer',
    'vacuolisation_and_damage_of_basal_layer',
    'spongiosis',
    'saw-tooth_appearance_of_retes',
    'follicular_horn_plug',
    'perifollicular_parakeratosis',
    'inflammatory_monoluclear_inflitrate',
    'band-like_infiltrate',
    'diagnosis'
]

# %%
clinical_data = data[clinical_columns]

# %%
clinical_data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
clinical_data.to_csv(os.path.join(DATA_ROOT, 'clinical_features.csv'))

# %%
pathology_data = data[pathology_columns]

# %%
pathology_data
# Out:
#      melanin_incontinence  eosinophils_in_the_infiltrate  PNL_infiltrate  \
# 0                       0                              0               0
# 1                       0                              0               1
# 2                       1                              0               0
# 3                       0                              0               3
# 4                       1                              0               0
# ..                    ...                            ...             ...
# 361                     0                              0               1
# 362                     0                              0               0
# 363                     2                              2               0
# 364                     2                              0               0
# 365                     0                              0               1
#
#      fibrosis_of_papillary_dermis  exocytosis  acanthosis  hyperkeratosis  \
# ...

# %%
pathology_data.to_csv(os.path.join(DATA_ROOT, 'pathology_features.csv'))
